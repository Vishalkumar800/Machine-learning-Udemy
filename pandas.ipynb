# %%
import pandas as pd
import numpy as np

# %%
data = np.array([1,2,4,5,8])
label = ["Vishal","Tom","A","B","C"]

pd.Series(data,index = label)
# Out:
# Vishal    1
# Tom       2
# A         4
# B         5
# C         8
# dtype: int32

# %%
data2 = {
    "Name": ["Vishal","Raj","Ali","Emma"],
    "Rollno" : [1,2,5,7],
    "Marks" : [100,90,33,67]
}

pd.DataFrame(data2)
# Out:
#      Name  Rollno  Marks
# 0  Vishal       1    100
# 1     Raj       2     90
# 2     Ali       5     33
# 3    Emma       7     67

# %%
data = pd.read_csv("heart_data.csv")
data
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 1    55.0        0                      7861         0                 38
# 2    65.0        0                       146         0                 20
# 3    50.0        1                       111         0                 20
# 4    65.0        1                       160         1                 20
# ..    ...      ...                       ...       ...                ...
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# ...

# %%
data.columns
# Out:
# Index(['age', 'anaemia', 'creatinine_phosphokinase', 'diabetes',
#        'ejection_fraction', 'high_blood_pressure', 'platelets',
#        'serum_creatinine', 'serum_sodium', 'sex', 'smoking', 'time',
#        'DEATH_EVENT'],
#       dtype='object')

# %%
data.loc[2]
# Out:
# age                             65.0
# anaemia                          0.0
# creatinine_phosphokinase       146.0
# diabetes                         0.0
# ejection_fraction               20.0
# high_blood_pressure              0.0
# platelets                   162000.0
# serum_creatinine                 1.3
# serum_sodium                   129.0
# sex                              1.0
# smoking                          1.0
# time                             7.0
# DEATH_EVENT                      1.0
# Name: 2, dtype: float64

# %%
data.loc[1,"creatinine_phosphokinase"]
# Out:
# 7861

# %%
data.iloc[1 , 2]
# Out:
# 7861

# %%
data.loc[1:4]
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 1  55.0        0                      7861         0                 38
# 2  65.0        0                       146         0                 20
# 3  50.0        1                       111         0                 20
# 4  65.0        1                       160         1                 20
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 1                    0  263358.03               1.1           136    1
# 2                    0  162000.00               1.3           129    1
# 3                    0  210000.00               1.9           137    1
# 4                    0  327000.00               2.7           116    0
#
#    smoking  time  DEATH_EVENT
# 1        0     6            1
# 2        1     7            1
# 3        0     7            1
# 4        0     8            1

# %%
data.iloc[1:5]
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 1  55.0        0                      7861         0                 38
# 2  65.0        0                       146         0                 20
# 3  50.0        1                       111         0                 20
# 4  65.0        1                       160         1                 20
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 1                    0  263358.03               1.1           136    1
# 2                    0  162000.00               1.3           129    1
# 3                    0  210000.00               1.9           137    1
# 4                    0  327000.00               2.7           116    0
#
#    smoking  time  DEATH_EVENT
# 1        0     6            1
# 2        1     7            1
# 3        0     7            1
# 4        0     8            1

# %%
data.loc[1:4 , "age":"platelets" ]
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 1  55.0        0                      7861         0                 38
# 2  65.0        0                       146         0                 20
# 3  50.0        1                       111         0                 20
# 4  65.0        1                       160         1                 20
#
#    high_blood_pressure  platelets
# 1                    0  263358.03
# 2                    0  162000.00
# 3                    0  210000.00
# 4                    0  327000.00

# %%
data.iloc[1:5 , 0: 7 ]
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 1  55.0        0                      7861         0                 38
# 2  65.0        0                       146         0                 20
# 3  50.0        1                       111         0                 20
# 4  65.0        1                       160         1                 20
#
#    high_blood_pressure  platelets
# 1                    0  263358.03
# 2                    0  162000.00
# 3                    0  210000.00
# 4                    0  327000.00

# %%
data.iloc[0:5, 1]
# Out:
# 0    0
# 1    0
# 2    0
# 3    1
# 4    1
# Name: anaemia, dtype: int64

# %%
data.loc[0:4 , "age"]
# Out:
# 0    75.0
# 1    55.0
# 2    65.0
# 3    50.0
# 4    65.0
# Name: age, dtype: float64
