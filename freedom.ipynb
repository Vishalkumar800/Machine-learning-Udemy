# %% [markdown]
# ## Summation (Σ)
#
# Definition:
# Summation means adding a series of numbers together.
#
# The symbol used for summation is Σ (Sigma).
#
# General Form:
# $$ \sum_{i=1}^{n} i $$
#
#
# “This means adding all the values of \(i\) from 1 to \(n\).”
#
#
# i=1+2+3+⋯+n

# %% [markdown]
# # Question
#
# Summation Practice Questions
#
# Q1. Find the value of:
#
# $$ \sum_{i=1}^{5} i $$
#
# Q2. Find the value of:
#
# $$ \sum_{i=1}^{10} i $$
#
# Q3. Find the value of:
#
# $$ \sum_{i=1}^{5} 2i $$
#
# Q4. Find the value of:
#
# $$ \sum_{i=1}^{4}(i+3) $$
#
# Q5. Find the value of:
#
# i=2
# ∑
# 6
# 	​

# %% [markdown]
# # Sum of natural number formula

# %% [markdown]
# ## 1. Sum of first \(n\) natural numbers
#
# ![Screenshot 2026-09-05 123458.png](<attachment:Screenshot 2026-09-05 123458.png>)
#
#
# ![Screenshot 2026-09-05 123617.png](<attachment:Screenshot 2026-09-05 123617.png>)

# %% [markdown]
# Practice Questions
#
# Q1. Find:
#
# $$ \sum_{i=1}^{10} i $$
#
# Q2. Find:
#
# $$ \sum_{i=1}^{5} i^2 $$
#
# Q3. Find:
#
# $$ \sum_{i=1}^{4} i^3 $$
#
# Q4. Find:
#
# $$ \sum_{i=1}^{20} 1 $$
#
# Q5. Find:
#
# $$ \sum_{i=1}^{8} i^2 $$
