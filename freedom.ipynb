# %% [markdown]
# ## Summation (Σ)
#
# Definition:
# Summation means adding a series of numbers together.
#
# The symbol used for summation is Σ (Sigma).
#
# General Form:
# $$ \sum_{i=1}^{n} i $$
#
#
# “This means adding all the values of \(i\) from 1 to \(n\).”
#
#
# i=1+2+3+⋯+n

# %% [markdown]
# # Question
#
# Summation Practice Questions
#
# Q1. Find the value of:
#
# $$ \sum_{i=1}^{5} i $$
#
# Q2. Find the value of:
#
# $$ \sum_{i=1}^{10} i $$
#
# Q3. Find the value of:
#
# $$ \sum_{i=1}^{5} 2i $$
#
# Q4. Find the value of:
#
# $$ \sum_{i=1}^{4}(i+3) $$
#
# Q5. Find the value of:
#
# i=2
# ∑
# 6
# 	​

# %% [markdown]
# # Sum of natural number formula

# %% [markdown]
# ## 1. Sum of first \(n\) natural numbers
#
# ![Screenshot](images/sumofn.png)
#
# ![Screenshot](images/sumofnsquare.png)

# %% [markdown]
# Practice Questions
#
# Q1. Find:
#
# $$ \sum_{i=1}^{10} i $$
#
# Q2. Find:
#
# $$ \sum_{i=1}^{5} i^2 $$
#
# Q3. Find:
#
# $$ \sum_{i=1}^{4} i^3 $$
#
# Q4. Find:
#
# $$ \sum_{i=1}^{20} 1 $$
#
# Q5. Find:
#
# $$ \sum_{i=1}^{8} i^2 $$

# %% [markdown]
# ## Measure of Central Tendancy
#
# Measure of Central Tendency is a statistical measure that describes the central or typical value of a dataset. It mainly includes Mean, Median, and Mode.
#
# ```
#
# Mean: The average value of the data.
# Mode: The value that occurs most frequently in a dataset.
# Median: The middle value of the data when the data is arranged in ascending or descending order.
#
#
# Question :
#
# 2, 2, 2, 3, 4, 4, 5, 5, 6, 8, 8, 8, 9, 9, 11, 23, 28, 28, 34, 36, 42 , 8 , 8
#
# ```

# %%
import numpy as np 

data = [2, 2, 2, 3, 4, 4, 5, 5, 6, 8, 8, 8, 9, 9, 11, 23, 28, 28, 34, 36, 42 , 8 , 8 ]

mean = np.mean(data)
median = np.median(data)

print(mean)
print(median)
# Out:
# 12.73913043478261
# 8.0

# %% [markdown]
# ### When Do We Use Mean, Median and Mode?
#
# **1. Mean – When the data is balanced**
#
# We use **Mean** when the data is relatively balanced and does not have extreme values (outliers).
#
# **Example:**
# `10, 12, 13, 14, 15`
#
# Here, the values are close to each other, so the **Mean** is a good measure of the center.
#
# ---
#
# **2. Median – When the data has outliers or is spread/skewed**
#
# We use **Median** when some values are very far away from the other values.
#
# **Example:**
# `10, 12, 13, 14, 100`
#
# Here, `100` is an outlier. It can make the Mean misleading, so we prefer the **Median**.
#
# ---
#
# **3. Mode – When repetition/frequency is important**
#
# We use **Mode** when we want to know which value occurs **most frequently**.
#
# **Example:**
# `2, 3, 3, 3, 5, 7`
#
# Here, `3` occurs most frequently, so the **Mode = 3**.
#
# Mode is also very useful for **categorical data**.
#
# **Example:**
# `Red, Blue, Red, Green, Red`
#
# Here, **Mode = Red** because Red occurs most frequently.
#
# ### Easy Rule to Remember
#
# * **Mean → Balanced data**
# * **Median → Outliers / Skewed data**
# * **Mode → Most frequent value**

# %% [markdown]
# # Percentage

# %% [markdown]
# ` percentage ` tells us how much you scored out of the total
#
# percentage =  ( Marked Obtained / TotalMarks ) * 100
#
# 1. A student scored 360 marks out of 500. What percentage did the student score?
#
# 2. In a class of 60 students, 40% are girls. How many boys are there?
#
# 3. A person's salary is ₹30,000 per month. If the salary increases by 20%, what will be the new salary?
#
# 4. What is 20% of 250?
#
# Ans =
#
# 1. 72%
#
# 2. 36 boys
#
# 3. ₹36,000
#
# 4. 50
#
# `Quantiles `
#
# ```
#
# Quantiles is a statistical measures used to divide a set of numerical data into equal sized groups with each group
# containing an equal number of observation
#
# There are serval types of quantiles used in statistical analysis
#
# 1. Quarties
#
# 2. Percentiles
#
# 3. Quintiles
#
# 4. Deciles
#
# ```
#
# ```
# Quarties : Divide data into 4 equally parts .
# It contains Q1, Q2 and Q3
#
# Quintiles : Divide the data into 5 eqaully parts
#
# Deciles : Divides the parts into equal parts
#
#
# ```

# %% [markdown]
# ## Percentiles :
#
# Percentiles tells you ,  how many people are you performed better than.
#
# Lets suppose in any exam you got 90 percentiles that means you performed better than 90 percentage students.
#
# ## Note :
# All data should be sorted from low to high .
#
# ```
#
# Percentiles = (P / 100) (N+1)
#
# P is the percentiles you want to find
# N is the number of obeservations in the data .
#
#
# 12, 18, 25, 30, 35, 42, 48, 55, 61, 67,
# 72, 78, 81, 85, 90
#
# 1. Find the 50th percentile (P50).
# 2. Find the 75th percentile (P75).
# 3. Find the 25th percentile (P25).
# 4. Find the 90th percentile (P90).
#
# 1. A student is ranked 20th among 100 students. If 79 students scored lower than him, what is his percentile?
# 2. In a class of 200 students, Rahul scored higher than 180 students. What is Rahul's percentile?
# 3. A student is at the 90th percentile in an exam. What does this mean?
# 4. In a competition, there are 500 participants. Aman scored higher than 425 participants. What is his percentile?
# 5. A student is at the 75th percentile among 400 students. Approximately how many students scored lower than him?
# 6. Riya's percentile is 82. What percentage of students scored lower than Riya?
#
# ```

# %% [markdown]
# #  IQR(Inter Quartile Range)

# %%
import numpy as np
x=  [0,1,20,21,22,23,24,25,30,90,100]

np.percentile(x,[25,75])

IQR = 27.5 - 20.5
print(IQR)

outlierstart = 20.5 - (1.5 * IQR)
outlierend = 27.5 +(1.5 * IQR)

ans = [outlierstart,outlierend]
ans
# Out:
# 7.0
# [10.0, 38.0]
